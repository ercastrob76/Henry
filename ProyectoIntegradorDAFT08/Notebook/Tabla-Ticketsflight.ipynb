# %%
#Cargar las librerias a utilizar
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Leer el Dataframe
ticketsflightdf = pd.read_csv(r'C:\Users\flore\OneDrive\Documents\Proyecto Final Clonado\ProyectoIntegradorDAFT08\Data\Data Original\ticket_flights.csv')

# %%
# Mostrar los tipos de datos de las columnas
print("Tipos de datos para la tabla 'ticketsflightdf':")
print(ticketsflightdf.dtypes)
# Out:
# Tipos de datos para la tabla 'ticketsflightdf':
# ticket_no           int64
# flight_id           int64
# fare_conditions    object
# amount              int64
# dtype: object

# %%
np.shape(ticketsflightdf)
# Out:
# (1045726, 4)

# %%
ticketsflightdf.head()
# Out:
#     ticket_no  flight_id fare_conditions  amount
# 0  5432159776      30625        Business   42100
# 1  5435212351      30625        Business   42100
# 2  5435212386      30625        Business   42100
# 3  5435212381      30625        Business   42100
# 4  5432211370      30625        Business   42100

# %%
# Eliminar filas donde todas las columnas son nulas
ticketsflightdf = ticketsflightdf.dropna(how='all')
# Eliminar columnas donde todas las filas son nulas
ticketsflightdf = ticketsflightdf.dropna(axis=1, how='all')

# %%
# Comprobar valores nulos
print(ticketsflightdf.isnull().sum())
# Out:
# ticket_no          0
# flight_id          0
# fare_conditions    0
# amount             0
# dtype: int64

# %%
# Configurar pandas para mostrar los números con formato legible
pd.options.display.float_format = '{:,.2f}'.format

# Ver las estadísticas descriptivas formateadas
print(ticketsflightdf['amount'].describe())
# Out:
# count   1,045,726.00
# mean       19,858.91
# std        22,612.39
# min         3,000.00
# 25%         7,200.00
# 50%        13,400.00
# 75%        23,100.00
# max       203,300.00
# Name: amount, dtype: float64

# %%
# Gráfico de barras: Monto promedio por condiciones de tarifa
plt.figure(figsize=(10, 3))
sns.barplot(x='fare_conditions', y='amount', data=ticketsflightdf)
plt.title('Monto Promedio por Condición de Tarifa')
plt.xlabel('Condición de Tarifa')
plt.ylabel('Monto Promedio')
plt.show()

# %%
plt.figure(figsize=(10, 3))
sns.countplot(x='fare_conditions', data=ticketsflightdf)
plt.title('Conteo de Boletos por Condición de Tarifa')
plt.xlabel('Condición de Tarifa')
plt.ylabel('Número de Boletos')
plt.show()

# %%
ticketsflightdf.to_csv("ticketsflight_data_clean.csv", index=False)
